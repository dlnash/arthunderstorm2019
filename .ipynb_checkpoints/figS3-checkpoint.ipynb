# %%
import logging
logging.captureWarnings(True)
logging.getLogger('py.warnings').setLevel(logging.ERROR)

import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import Image, display
from dask.distributed import Client, progress
from datetime import datetime, timedelta
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import matplotlib.ticker as mticker
import matplotlib.path as mpath
import matplotlib.patheffects as PathEffects
from scipy import stats
import scipy
import numpy.ma as ma
from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.axes_grid1 import ImageGrid
from scipy.ndimage import gaussian_filter

from modules.plotter import make_cmap
# %matplotlib inline

# %%
def preprocess(ds):
    '''keep only the selected lats and lons'''
    return ds.sel(latitude=slice(10,50), longitude=slice(210,250))

filename_pattern =  '/home/sbarc/students/nash/data/CFSv2/netcdf_CFSv2_vertical_levels/201*'
ds = xr.open_mfdataset(filename_pattern, engine='netcdf4', preprocess=preprocess)
print('ds size in GB {:0.2f}\n'.format(ds.nbytes / 1e9))
ds.info()
# Out:
# ds size in GB 0.13
#
# xarray.Dataset {
# dimensions:
# 	latitude = 81 ;
# 	longitude = 81 ;
# 	p = 37 ;
# 	time = 9 ;
#
# variables:
# 	float64 latitude(latitude) ;
# 		latitude:units = degrees_north ;
# 		latitude:long_name = latitude ;
# 	float64 longitude(longitude) ;
# 		longitude:units = degrees_east ;
# 		longitude:long_name = longitude ;
# 	float32 p(p) ;
# 		p:lev_type = 100 ;
# 		p:units = mb ;
# 		p:long_name = p����* ;
# 	datetime64[ns] time(time) ;
# 		time:long_name = verification time generated by wgrib2 function verftime() ;
# 		time:reference_time_type = 1 ;
# 		time:reference_time_description = analyses, reference date is fixed ;
# 		time:time_step_setting = auto ;
# 		time:time_step = 0.0 ;
# 	float32 prmsl(time, latitude, longitude) ;
# 		prmsl:short_name = prmsl ;
# 		prmsl:long_name = Pressure ;
# 		prmsl:level = mean sea level ;
# 		prmsl:units = Pa ;
# 	float32 hgtprs(time, p, latitude, longitude) ;
# 		hgtprs:short_name = hgtprs ;
# 		hgtprs:long_name = Geopotential Height ;
# 		hgtprs:level = ��M ;
# 		hgtprs:units = m ;
# 	float32 temp(time, p, latitude, longitude) ;
# 		temp:short_name = temp ;
# 		temp:long_name = Temperature ;
# 		temp:level = @�M ;
# 		temp:units = K ;
# 	float32 rh(time, p, latitude, longitude) ;
# 		rh:short_name = rh ;
# 		rh:long_name = Relative Humidity ;
# 		rh:units = percent ;
# 	float32 spfh(time, p, latitude, longitude) ;
# 		spfh:short_name = spfh ;
# 		spfh:long_name = Specific Humidity ;
# 		spfh:level = �N ;
# 		spfh:units = kg/kg ;
# 	float32 omega(time, p, latitude, longitude) ;
# 		omega:short_name = omega ;
# 		omega:long_name = Vertical Velocity (Pressure) ;
# 		omega:level =  ;
# 		omega:units = Pa/s ;
# 	float32 u(time, p, latitude, longitude) ;
# 		u:short_name = u ;
# 		u:long_name = U-Component of Wind ;
# 		u:level = ��M ;
# 		u:units = m/s ;
# 	float32 v(time, p, latitude, longitude) ;
# 		v:short_name = v ;
# 		v:long_name = V-Component of Wind ;
# 		v:level = `�M ;
# 		v:units = m/s ;
# 	float32 absv(time, p, latitude, longitude) ;
# 		absv:short_name = absv ;
# 		absv:long_name = Absolute Vorticity ;
# 		absv:level = pN ;
# 		absv:units = 1/s ;
# 	float32 ozonemixing(time, p, latitude, longitude) ;
# 		ozonemixing:short_name = ozonemixing ;
# 		ozonemixing:long_name = Ozone Mixing Ratio ;
# 		ozonemixing:units = kg/kg ;
# 	float32 cloudmixing(time, p, latitude, longitude) ;
# 		cloudmixing:short_name = cloudmixing ;
# 		cloudmixing:long_name = Cloud Mixing Ratio ;
# 		cloudmixing:level =  ;
# 		cloudmixing:units = kg/kg ;
# 	float32 DPT_2maboveground(time, latitude, longitude) ;
# 		DPT_2maboveground:short_name = DPT_2maboveground ;
# 		DPT_2maboveground:long_name = Dew Point Temperature ;
# 		DPT_2maboveground:level = 2 m above ground ;
# 		DPT_2maboveground:units = K ;
# 	float32 RH_2maboveground(time, latitude, longitude) ;
# 		RH_2maboveground:short_name = RH_2maboveground ;
# 		RH_2maboveground:long_name = Relative Humidity ;
# 		RH_2maboveground:level = 2 m above ground ;
# 		RH_2maboveground:units = percent ;
# 	float32 APCP_surface(time, latitude, longitude) ;
# 		APCP_surface:short_name = APCP_surface ;
# 		APCP_surface:long_name = Total Precipitation ;
# 		APCP_surface:level = surface ;
# 		APCP_surface:units = kg/m^2 ;
# 	float32 ACPCP_surface(time, latitude, longitude) ;
# 		ACPCP_surface:short_name = ACPCP_surface ;
# 		ACPCP_surface:long_name = Convective Precipitation ;
# 		ACPCP_surface:level = surface ;
# 		ACPCP_surface:units = kg/m^2 ;
# 	float32 NCPCP_surface(time, latitude, longitude) ;
# 		NCPCP_surface:short_name = NCPCP_surface ;
# 		NCPCP_surface:long_name = Large-Scale Precipitation (non-convective) ;
# 		NCPCP_surface:level = surface ;
# 		NCPCP_surface:units = kg/m^2 ;
# 	float32 CSNOW_surface(time, latitude, longitude) ;
# 		CSNOW_surface:short_name = CSNOW_surface ;
# 		CSNOW_surface:long_name = Categorical Snow ;
# 		CSNOW_surface:level = surface ;
# 		CSNOW_surface:units = - ;
# 	float32 CICEP_surface(time, latitude, longitude) ;
# 		CICEP_surface:short_name = CICEP_surface ;
# 		CICEP_surface:long_name = Categorical Ice Pellets ;
# 		CICEP_surface:level = surface ;
# 		CICEP_surface:units = - ;
# 	float32 CFRZR_surface(time, latitude, longitude) ;
# 		CFRZR_surface:short_name = CFRZR_surface ;
# 		CFRZR_surface:long_name = Categorical Freezing Rain ;
# 		CFRZR_surface:level = surface ;
# 		CFRZR_surface:units = - ;
# 	float32 LFTX_surface(time, latitude, longitude) ;
# 		LFTX_surface:short_name = LFTX_surface ;
# 		LFTX_surface:long_name = Surface Lifted Index ;
# 		LFTX_surface:level = surface ;
# 		LFTX_surface:units = K ;
# 	float32 capesfc(time, latitude, longitude) ;
# 		capesfc:short_name = capesfc ;
# 		capesfc:long_name = Convective Available Potential Energy ;
# 		capesfc:level = surface ;
# 		capesfc:units = J/kg ;
# 	float32 cinsfc(time, latitude, longitude) ;
# 		cinsfc:short_name = cinsfc ;
# 		cinsfc:long_name = Convective Inhibition ;
# 		cinsfc:level = surface ;
# 		cinsfc:units = J/kg ;
# 	float32 cwat(time, latitude, longitude) ;
# 		cwat:short_name = cwat ;
# 		cwat:long_name = Cloud Water ;
# 		cwat:level = entire atmosphere (considered as a single layer) ;
# 		cwat:units = kg/m^2 ;
# 	float32 prestrop(time, latitude, longitude) ;
# 		prestrop:short_name = prestrop ;
# 		prestrop:long_name = Pressure ;
# 		prestrop:level = tropopause ;
# 		prestrop:units = Pa ;
# 	float32 hgt_0Cisotherm(time, latitude, longitude) ;
# 		hgt_0Cisotherm:short_name = hgt_0Cisotherm ;
# 		hgt_0Cisotherm:long_name = Geopotential Height ;
# 		hgt_0Cisotherm:level = 0C isotherm ;
# 		hgt_0Cisotherm:units = m ;
# 	float32 rh_0Cisotherm(time, latitude, longitude) ;
# 		rh_0Cisotherm:short_name = rh_0Cisotherm ;
# 		rh_0Cisotherm:long_name = Relative Humidity ;
# 		rh_0Cisotherm:level = 0C isotherm ;
# 		rh_0Cisotherm:units = percent ;
# 	float32 PRMSL_meansealevel(time, latitude, longitude) ;
# 		PRMSL_meansealevel:short_name = PRMSL_meansealevel ;
# 		PRMSL_meansealevel:long_name = Pressure Reduced to MSL ;
# 		PRMSL_meansealevel:level = mean sea level ;
# 		PRMSL_meansealevel:units = Pa ;
# 	float32 GPA(time, p, latitude, longitude) ;
# 		GPA:short_name = GPA ;
# 		GPA:long_name = Geopotential Height Anomaly ;
# 		GPA:level = 0�M ;
# 		GPA:units = m ;
# 	float32 strm(time, p, latitude, longitude) ;
# 		strm:short_name = strm ;
# 		strm:long_name = Stream Function ;
# 		strm:level = 0�M ;
# 		strm:units = m^2/s ;
# 	float32 vpot(time, p, latitude, longitude) ;
# 		vpot:short_name = vpot ;
# 		vpot:long_name = Velocity Potential ;
# 		vpot:level = �(L ;
# 		vpot:units = m^2/s ;
# 	float32 UFLX_surface(time, latitude, longitude) ;
# 		UFLX_surface:short_name = UFLX_surface ;
# 		UFLX_surface:long_name = Momentum Flux, U-Component ;
# 		UFLX_surface:level = surface ;
# 		UFLX_surface:units = N/m^2 ;
# 	float32 VFLX_surface(time, latitude, longitude) ;
# 		VFLX_surface:short_name = VFLX_surface ;
# 		VFLX_surface:long_name = Momentum Flux, V-Component ;
# 		VFLX_surface:level = surface ;
# 		VFLX_surface:units = N/m^2 ;
# 	float32 lhtfl(time, latitude, longitude) ;
# 		lhtfl:short_name = lhtfl ;
# 		lhtfl:long_name = Latent Heat Net Flux ;
# 		lhtfl:level = surface ;
# 		lhtfl:units = W/m^2 ;
# 	float32 tmpsfc(time, latitude, longitude) ;
# 		tmpsfc:short_name = tmpsfc ;
# 		tmpsfc:long_name = Temperature ;
# 		tmpsfc:level = surface ;
# 		tmpsfc:units = K ;
# 	float32 ULWRF_topofatmosphere(time, latitude, longitude) ;
# 		ULWRF_topofatmosphere:short_name = ULWRF_topofatmosphere ;
# 		ULWRF_topofatmosphere:long_name = Upward Long-Wave Rad. Flux ;
# 		ULWRF_topofatmosphere:level = top of atmosphere ;
# 		ULWRF_topofatmosphere:units = W/m^2 ;
# 	float32 USWRF_topofatmosphere(time, latitude, longitude) ;
# 		USWRF_topofatmosphere:short_name = USWRF_topofatmosphere ;
# 		USWRF_topofatmosphere:long_name = Upward Short-Wave Radiation Flux ;
# 		USWRF_topofatmosphere:level = top of atmosphere ;
# 		USWRF_topofatmosphere:units = W/m^2 ;
# 	float32 CDUVB_surface(time, latitude, longitude) ;
# 		CDUVB_surface:short_name = CDUVB_surface ;
# 		CDUVB_surface:long_name = Clear sky UV-B Downward Solar Flux ;
# 		CDUVB_surface:level = surface ;
# 		CDUVB_surface:units = W/m^2 ;
# 	float32 PRES_highcloudtoplevel(time, latitude, longitude) ;
# 		PRES_highcloudtoplevel:short_name = PRES_highcloudtoplevel ;
# 		PRES_highcloudtoplevel:long_name = Pressure ;
# 		PRES_highcloudtoplevel:level = high cloud top level ;
# 		PRES_highcloudtoplevel:units = Pa ;
# 	float32 PRES_highcloudbottomlevel(time, latitude, longitude) ;
# 		PRES_highcloudbottomlevel:short_name = PRES_highcloudbottomlevel ;
# 		PRES_highcloudbottomlevel:long_name = Pressure ;
# 		PRES_highcloudbottomlevel:level = high cloud bottom level ;
# 		PRES_highcloudbottomlevel:units = Pa ;
# 	float32 TMP_highcloudtoplevel(time, latitude, longitude) ;
# 		TMP_highcloudtoplevel:short_name = TMP_highcloudtoplevel ;
# 		TMP_highcloudtoplevel:long_name = Temperature ;
# 		TMP_highcloudtoplevel:level = high cloud top level ;
# 		TMP_highcloudtoplevel:units = K ;
# 	float32 PRES_middlecloudtoplevel(time, latitude, longitude) ;
# 		PRES_middlecloudtoplevel:short_name = PRES_middlecloudtoplevel ;
# 		PRES_middlecloudtoplevel:long_name = Pressure ;
# 		PRES_middlecloudtoplevel:level = middle cloud top level ;
# 		PRES_middlecloudtoplevel:units = Pa ;
# 	float32 PRES_middlecloudbottomlevel(time, latitude, longitude) ;
# 		PRES_middlecloudbottomlevel:short_name = PRES_middlecloudbottomlevel ;
# 		PRES_middlecloudbottomlevel:long_name = Pressure ;
# 		PRES_middlecloudbottomlevel:level = middle cloud bottom level ;
# 		PRES_middlecloudbottomlevel:units = Pa ;
# 	float32 TMP_middlecloudtoplevel(time, latitude, longitude) ;
# 		TMP_middlecloudtoplevel:short_name = TMP_middlecloudtoplevel ;
# 		TMP_middlecloudtoplevel:long_name = Temperature ;
# 		TMP_middlecloudtoplevel:level = middle cloud top level ;
# 		TMP_middlecloudtoplevel:units = K ;
# 	float32 PRES_lowcloudtoplevel(time, latitude, longitude) ;
# 		PRES_lowcloudtoplevel:short_name = PRES_lowcloudtoplevel ;
# 		PRES_lowcloudtoplevel:long_name = Pressure ;
# 		PRES_lowcloudtoplevel:level = low cloud top level ;
# 		PRES_lowcloudtoplevel:units = Pa ;
# 	float32 PRES_lowcloudbottomlevel(time, latitude, longitude) ;
# 		PRES_lowcloudbottomlevel:short_name = PRES_lowcloudbottomlevel ;
# 		PRES_lowcloudbottomlevel:long_name = Pressure ;
# 		PRES_lowcloudbottomlevel:level = low cloud bottom level ;
# 		PRES_lowcloudbottomlevel:units = Pa ;
# 	float32 TMP_lowcloudtoplevel(time, latitude, longitude) ;
# 		TMP_lowcloudtoplevel:short_name = TMP_lowcloudtoplevel ;
# 		TMP_lowcloudtoplevel:long_name = Temperature ;
# 		TMP_lowcloudtoplevel:level = low cloud top level ;
# 		TMP_lowcloudtoplevel:units = K ;
# 	float32 prate(time, latitude, longitude) ;
# 		prate:short_name = prate ;
# 		prate:long_name = Precipitation Rate ;
# 		prate:level = surface ;
# 		prate:units = kg/m^2/s ;
# 	float32 CPRAT_surface(time, latitude, longitude) ;
# 		CPRAT_surface:short_name = CPRAT_surface ;
# 		CPRAT_surface:long_name = Convective Precipitation Rate ;
# 		CPRAT_surface:level = surface ;
# 		CPRAT_surface:units = kg/m^2/s ;
# 	float32 landmask(time, latitude, longitude) ;
# 		landmask:short_name = landmask ;
# 		landmask:long_name = Land Cover (0=sea, 1=land) ;
# 		landmask:level = surface ;
# 		landmask:units = Proportion ;
# 	float32 prsfc(time, latitude, longitude) ;
# 		prsfc:short_name = prsfc ;
# 		prsfc:long_name = Pressure ;
# 		prsfc:level = surface ;
# 		prsfc:units = Pa ;
# 	float32 TMAX_2maboveground(time, latitude, longitude) ;
# 		TMAX_2maboveground:short_name = TMAX_2maboveground ;
# 		TMAX_2maboveground:long_name = Maximum Temperature ;
# 		TMAX_2maboveground:level = 2 m above ground ;
# 		TMAX_2maboveground:units = K ;
# 	float32 TMIN_2maboveground(time, latitude, longitude) ;
# 		TMIN_2maboveground:short_name = TMIN_2maboveground ;
# 		TMIN_2maboveground:long_name = Minimum Temperature ;
# 		TMIN_2maboveground:level = 2 m above ground ;
# 		TMIN_2maboveground:units = K ;
# 	float32 QMAX_2maboveground(time, latitude, longitude) ;
# 		QMAX_2maboveground:short_name = QMAX_2maboveground ;
# 		QMAX_2maboveground:long_name = Maximum specific humidity at 2m ;
# 		QMAX_2maboveground:level = 2 m above ground ;
# 		QMAX_2maboveground:units = kg/kg ;
# 	float32 QMIN_2maboveground(time, latitude, longitude) ;
# 		QMIN_2maboveground:short_name = QMIN_2maboveground ;
# 		QMIN_2maboveground:long_name = Minimum specific humidity at 2m ;
# 		QMIN_2maboveground:level = 2 m above ground ;
# 		QMIN_2maboveground:units = kg/kg ;
# 	float32 WATR_surface(time, latitude, longitude) ;
# 		WATR_surface:short_name = WATR_surface ;
# 		WATR_surface:long_name = Water Runoff ;
# 		WATR_surface:level = surface ;
# 		WATR_surface:units = kg/m^2 ;
# 	float32 evapsfc(time, latitude, longitude) ;
# 		evapsfc:short_name = evapsfc ;
# 		evapsfc:long_name = Potential Evaporation Rate ;
# 		evapsfc:level = surface ;
# 		evapsfc:units = W/m^2 ;
# 	float32 UMGWD_surface(time, latitude, longitude) ;
# 		UMGWD_surface:short_name = UMGWD_surface ;
# 		UMGWD_surface:long_name = Zonal Flux of Gravity Wave Stress ;
# 		UMGWD_surface:level = surface ;
# 		UMGWD_surface:units = N/m^2 ;
# 	float32 VMGWD_surface(time, latitude, longitude) ;
# 		VMGWD_surface:short_name = VMGWD_surface ;
# 		VMGWD_surface:long_name = Meridional Flux of Gravity Wave Stress ;
# 		VMGWD_surface:level = surface ;
# 		VMGWD_surface:units = N/m^2 ;
# 	float32 ALBDO_surface(time, latitude, longitude) ;
# 		ALBDO_surface:short_name = ALBDO_surface ;
# 		ALBDO_surface:long_name = Albedo ;
# 		ALBDO_surface:level = surface ;
# 		ALBDO_surface:units = percent ;
# 	float32 hgtsfc(time, latitude, longitude) ;
# 		hgtsfc:short_name = hgtsfc ;
# 		hgtsfc:long_name = Geopotential Height ;
# 		hgtsfc:level = surface ;
# 		hgtsfc:units = m ;
# 	float32 SSRUN_surface(time, latitude, longitude) ;
# 		SSRUN_surface:short_name = SSRUN_surface ;
# 		SSRUN_surface:long_name = Storm Surface Runoff ;
# 		SSRUN_surface:level = surface ;
# 		SSRUN_surface:units = kg/m^2 ;
# 	float32 EVBS_surface(time, latitude, longitude) ;
# 		EVBS_surface:short_name = EVBS_surface ;
# 		EVBS_surface:long_name = Direct Evaporation from Bare Soil ;
# 		EVBS_surface:level = surface ;
# 		EVBS_surface:units = W/m^2 ;
# 	float32 EVCW_surface(time, latitude, longitude) ;
# 		EVCW_surface:short_name = EVCW_surface ;
# 		EVCW_surface:long_name = Canopy water evaporation ;
# 		EVCW_surface:level = surface ;
# 		EVCW_surface:units = W/m^2 ;
# 	float32 TRANS_surface(time, latitude, longitude) ;
# 		TRANS_surface:short_name = TRANS_surface ;
# 		TRANS_surface:long_name = Transpiration ;
# 		TRANS_surface:level = surface ;
# 		TRANS_surface:units = W/m^2 ;
# 	float32 SBSNO_surface(time, latitude, longitude) ;
# 		SBSNO_surface:short_name = SBSNO_surface ;
# 		SBSNO_surface:long_name = Sublimation (evaporation from snow) ;
# 		SBSNO_surface:level = surface ;
# 		SBSNO_surface:units = W/m^2 ;
# 	float32 SNOWC_surface(time, latitude, longitude) ;
# 		SNOWC_surface:short_name = SNOWC_surface ;
# 		SNOWC_surface:long_name = Snow Cover ;
# 		SNOWC_surface:level = surface ;
# 		SNOWC_surface:units = percent ;
# 	float32 CSULF_topofatmosphere(time, latitude, longitude) ;
# 		CSULF_topofatmosphere:short_name = CSULF_topofatmosphere ;
# 		CSULF_topofatmosphere:long_name = Clear Sky Upward Long Wave Flux ;
# 		CSULF_topofatmosphere:level = top of atmosphere ;
# 		CSULF_topofatmosphere:units = W/m^2 ;
# 	float32 CSUSF_topofatmosphere(time, latitude, longitude) ;
# 		CSUSF_topofatmosphere:short_name = CSUSF_topofatmosphere ;
# 		CSUSF_topofatmosphere:long_name = Clear Sky Upward Solar Flux ;
# 		CSUSF_topofatmosphere:level = top of atmosphere ;
# 		CSUSF_topofatmosphere:units = W/m^2 ;
# 	float32 CSUSF_surface(time, latitude, longitude) ;
# 		CSUSF_surface:short_name = CSUSF_surface ;
# 		CSUSF_surface:long_name = Clear Sky Upward Solar Flux ;
# 		CSUSF_surface:level = surface ;
# 		CSUSF_surface:units = W/m^2 ;
# 	float32 CSULF_surface(time, latitude, longitude) ;
# 		CSULF_surface:short_name = CSULF_surface ;
# 		CSULF_surface:long_name = Clear Sky Upward Long Wave Flux ;
# 		CSULF_surface:level = surface ;
# 		CSULF_surface:units = W/m^2 ;
# 	float32 SNOHF_surface(time, latitude, longitude) ;
# 		SNOHF_surface:short_name = SNOHF_surface ;
# 		SNOHF_surface:long_name = Snow Phase Change Heat Flux ;
# 		SNOHF_surface:level = surface ;
# 		SNOHF_surface:units = W/m^2 ;
#
# // global attributes:
# 	:Conventions = COARDS ;
# 	:History = created by wgrib2 ;
# 	:GRIB2_grid_template = 0 ;
# }

# %%
da_SPFH = ds.spfh.sel(p=slice(1000,300))
da_V = ds.v.sel(p=slice(1000,300))
da_U = ds.u.sel(p=slice(1000,300))
pressure = ds.p.sel(p=slice(1000,300)).values

da_MSL = ds.prmsl
da_MSL = da_MSL/100 # convert to hPa

U_850 = ds.u.sel(p=850.0)* 1.94384 ## convert to knots
V_850 = ds.v.sel(p=850.0)* 1.94384 ## convert to knots

da_GPH = ds.hgtprs.sel(p=500.0)

da_CAPE = ds.capesfc

# %%
lats = ds['latitude']
lons = ds['longitude']

# %%
g = -9.81 # gravity constant
ivt_u = scipy.integrate.trapz(da_U*da_SPFH, pressure, axis=1)*g
print(ivt_u.shape)
ivt_v = scipy.integrate.trapz(da_V*da_SPFH, pressure, axis=1)*g
print(ivt_v.shape)
ivt_total = np.sqrt(ivt_u**2 + ivt_v**2)
# Out:
# (9, 81, 81)
# (9, 81, 81)

# %%
fig = plt.figure(figsize=(9,9))
fig.dpi = 600
fname = './figures/fS3'
fmt1 = 'png'
fmt2 = 'pdf'
results = da_CAPE
subtitles = ['(a) 4 March 2019 18 UTC', 
             '(b) 5 March 2019 00 UTC', '(c) 5 March 2019 06 UTC', '(d) 5 March 2019 12 UTC',
             '(e) 5 March 2019 18 UTC',
            '(f) 6 March 2019 00 UTC', '(g) 6 March 2019 06 UTC', '(h) 6 March 2019 12 UTC',
             '(i) 6 March 2019 18 UTC']

lats = ds['latitude']
lons = ds['longitude']
# Set up projection
mapcrs = ccrs.PlateCarree()
datacrs = ccrs.PlateCarree()

# Create a feature for States/Admin 1 regions at 1:50m from Natural Earth
states_provinces = cfeature.NaturalEarthFeature(
    category='cultural',
    name='admin_1_states_provinces_lines',
    scale='50m',
    facecolor='none')

for i in np.arange(len(results)):
    ax = plt.subplot(3, 3, i+1, projection=ccrs.PlateCarree())
    ax.set_extent([lons.min(), lons.max(), lats.min(), lats.max()], crs=ccrs.PlateCarree())
    
    # Add Border Features
    ax.coastlines(linewidths=1.0, resolution='10m')
    ax.add_feature(states_provinces, edgecolor='k')
    ax.add_feature(cfeature.BORDERS)
    
    
    # Plot CAPE
    capeclevs = np.arange(100,1100,100)
    cf = ax.contourf(lons, lats, da_CAPE[i], transform=datacrs,
                     extend='max', cmap='jet', levels=capeclevs)
    
    # Plot IVT countours
    ivtclevs = np.arange(250,1150,100)
    cs = ax.contour(lons, lats, ivt_total[i], ivtclevs, colors='dimgrey', linewidths=0.5,
                      linestyles='solid', transform=datacrs)

    # Plot GPH with multiple colors
    kw_clabels = {'fontsize': 5, 'inline': True, 'inline_spacing': 5, 'fmt': '%i',
                  'rightside_up': True, 'use_clabeltext': True}
    clevsgph = (np.arange(0, 5430, 60),
         np.array([5430]),
         np.arange(5460, 7000, 60))
    colors = ('tab:blue', 'b', 'tab:red')
    for clevthick, color in zip(clevsgph, colors):
        cs = ax.contour(lons, lats, da_GPH[i,:,:], levels=clevthick, colors='k',
                        linewidths=0.5, linestyles='dashed', transform=datacrs)
        plt.clabel(cs, **kw_clabels)

#     # Plot MSLP
#     mslp_sm = gaussian_filter(da_MSL[i,:,:], sigma=1.5)
#     clevmslp = np.arange(800., 1120., 4)
#     cs2 = ax.contour(lons, lats, da_MSL[i,:,:], clevmslp, colors='grey', linewidths=1.,
#                      linestyles='solid', transform=datacrs)
#     plt.clabel(cs2, **kw_clabels)
    
    
    ax.set_title(subtitles[i], fontsize=10)
    ## Add in meridian and parallels
    gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=.5, color='black', alpha=0.5, linestyle='--')
    gl.xlabels_top = False
    gl.ylabels_right = False
    gl.xlocator = mticker.FixedLocator([-150, -140, -130, -120, -110])
    gl.ylocator = mticker.FixedLocator([10,20, 30, 40, 50])
    gl.xformatter = LONGITUDE_FORMATTER
    gl.yformatter = LATITUDE_FORMATTER
    gl.xlabel_style = {'size': 7}
    gl.ylabel_style = {'size': 7}

# # add colorbar [left, bottom, width, height]
ax2 = fig.add_axes([0.9, 0.13, 0.03, 0.75])
cbar = fig.colorbar(cf, cax=ax2, drawedges=True, 
                    orientation='vertical', extendfrac='auto')
cbar.ax.tick_params(labelsize=8)
cbar.set_label(r'$\mathrm{CAPE \:(J\:kg^{-1})}$', fontsize=12)

plt.subplots_adjust(hspace=0.2, wspace=0.003)

fig.savefig('%s.%s' %(fname, fmt1), bbox_inches='tight', dpi=fig.dpi)
fig.savefig('%s.%s' %(fname, fmt2), bbox_inches='tight', dpi=fig.dpi)
fig.clf()


plotFile = fname + '.png'
print(plotFile)
display(Image(plotFile))
